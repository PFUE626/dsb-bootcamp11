# %%
import pandas as pd
df = pd.read_csv("sample-store.csv")

# %%
sample_df = df.head(10)

# %%
df.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 1        2  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2        3  CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 12      13  CA-2020-114412 2020-04-15 2020-04-20  Standard Class    AA-10480
# 13      14  CA-2019-161389 2019-12-05 2019-12-10  Standard Class    IM-15070
#
#       Customer Name    Segment Country/Region         City  ...  \
# 0       Claire Gute   Consumer  United States    Henderson  ...
# 1       Claire Gute   Consumer  United States    Henderson  ...
# 2   Darrin Van Huff  Corporate  United States  Los Angeles  ...
# 12     Andrew Allen   Consumer  United States      Concord  ...
# 13     Irene Maddox   Consumer  United States      Seattle  ...
#
#          Product ID         Category Sub-Category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   OFF-LA-10000240  Office Supplies       Labels
# 12  OFF-PA-10002365  Office Supplies        Paper
# 13  OFF-BI-10003656  Office Supplies      Binders
#
#                                          Product Name    Sales Quantity  \
# 0                   Bush Somerset Collection Bookcase  261.960        2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940        3
# 2   Self-Adhesive Address Labels for Typewriters b...   14.620        2
# 12                                         Xerox 1967   15.552        3
# 13        Fellowes PB200 Plastic Comb Binding Machine  407.976        3
#
#    Discount    Profit  Profit_Status  High_Discount
# 0       0.0   41.9136   Unprofitable             No
# 1       0.0  219.5820     Profitable             No
# 2       0.0    6.8714   Unprofitable             No
# 12      0.2    5.4432   Unprofitable            Yes
# 13      0.2  132.5922   Unprofitable            Yes
#
# [5 rows x 23 columns]

# %%
# TODO - convert order date and ship date to datetime in the original dataframe
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
print(df[['Order Date', 'Ship Date']].head())
# Out:
#    Order Date  Ship Date
# 0  2019-11-08 2019-11-11
# 1  2019-11-08 2019-11-11
# 2  2019-06-12 2019-06-16
# 12 2020-04-15 2020-04-20
# 13 2019-12-05 2019-12-10

# %%
# TODO - count nan in postal code column
nan_count = df['Postal Code'].isna().sum()
print("Number of NaN values in 'Postal Code' column:", nan_count)
# Out:
# Number of NaN values in 'Postal Code' column: 9

# %%
# TODO - filter rows with missing values
missing_rows = df[df.isna().any(axis=1)]
missing_rows
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2234    2235  CA-2020-104066 2020-12-05 2020-12-10  Standard Class
# 8798    8799  US-2019-150140 2019-04-06 2019-04-10  Standard Class
# 9146    9147  US-2019-165505 2019-01-23 2019-01-27  Standard Class
# 9147    9148  US-2019-165505 2019-01-23 2019-01-27  Standard Class
# 9148    9149  US-2019-165505 2019-01-23 2019-01-27  Standard Class
# 9386    9387  US-2020-127292 2020-01-19 2020-01-23  Standard Class
# 9387    9388  US-2020-127292 2020-01-19 2020-01-23  Standard Class
# 9388    9389  US-2020-127292 2020-01-19 2020-01-23  Standard Class
# 9389    9390  US-2020-127292 2020-01-19 2020-01-23  Standard Class
#
#      Customer ID     Customer Name      Segment Country/Region        City  \
# 2234    QJ-19255      Quincy Jones    Corporate  United States  Burlington
# 8798    VM-21685   Valerie Mitchum  Home Office  United States  Burlington
# 9146    CB-12535  Claudia Bergmann    Corporate  United States  Burlington
# 9147    CB-12535  Claudia Bergmann    Corporate  United States  Burlington
# 9148    CB-12535  Claudia Bergmann    Corporate  United States  Burlington
# 9386    RM-19375     Raymond Messe     Consumer  United States  Burlington
# 9387    RM-19375     Raymond Messe     Consumer  United States  Burlington
# 9388    RM-19375     Raymond Messe     Consumer  United States  Burlington
# 9389    RM-19375     Raymond Messe     Consumer  United States  Burlington
#
#       ...       Product ID         Category Sub-Category  \
# 2234  ...  TEC-AC-10001013       Technology  Accessories
# 8798  ...  TEC-PH-10002555       Technology       Phones
# 9146  ...  TEC-AC-10002926       Technology  Accessories
# 9147  ...  OFF-AR-10003477  Office Supplies          Art
# 9148  ...  OFF-ST-10001526  Office Supplies      Storage
# 9386  ...  OFF-PA-10000157  Office Supplies        Paper
# 9387  ...  OFF-PA-10001970  Office Supplies        Paper
# 9388  ...  OFF-AP-10000828  Office Supplies   Appliances
# 9389  ...  OFF-EN-10001509  Office Supplies    Envelopes
#
#                                      Product Name    Sales Quantity Discount  \
# 2234  Logitech ClearChat Comfort/USB Headset H390   205.03        7      0.0
# 8798          Nortel Meridian M5316 Digital phone  1294.75        5      0.0
# 9146        Logitech Wireless Marathon Mouse M705    99.98        2      0.0
# 9147                            4009 Highlighters     8.04        6      0.0
# 9148        Iceberg Mobile Mega Data/Printer Cart  1564.29       13      0.0
# 9386                                    Xerox 191    79.92        4      0.0
# 9387                                   Xerox 1881    12.28        1      0.0
# 9388              Avanti 4.4 Cu. Ft. Refrigerator   542.94        3      0.0
# 9389                    Poly String Tie Envelopes     2.04        1      0.0
#
#         Profit  Profit_Status  High_Discount
# 2234   67.6599   Unprofitable             No
# 8798  336.6350     Profitable             No
# 9146   42.9914   Unprofitable             No
# 9147    2.7336   Unprofitable             No
# 9148  406.7154     Profitable             No
# 9386   37.5624   Unprofitable             No
# 9387    5.7716   Unprofitable             No
# 9388  152.0232   Unprofitable             No
# 9389    0.9588   Unprofitable             No
#
# [9 rows x 23 columns]
# Warning: Total number of columns (23) exceeds max_columns (20) limiting to first (20) columns.

# %%
# TODO 01 - how many columns, rows in this dataset
rows, columns = df.shape

# %%
df.shape
# Out:
# (5899, 23)

# %%
# TODO 02 - is there any missing values?, if there is, which colunm? how many nan values?
missing_values = df.isna().sum()
missing_values
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
missing_values[missing_values > 0]
# Out:
# Postal Code    11
# dtype: int64

# %%
 total_missing = df.isna().sum().sum()
 total_missing
# Out:
# np.int64(11)

# %%
# TODO 03 - your friend ask for `California` data, filter it and export csv for him
df_california = df[df['State'] == 'California']
df_california
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2          3  CA-2019-138688  6/12/2019  6/16/2019    Second Class
# 5          6  CA-2017-115812   6/9/2017  6/14/2017  Standard Class
# 6          7  CA-2017-115812   6/9/2017  6/14/2017  Standard Class
# 7          8  CA-2017-115812   6/9/2017  6/14/2017  Standard Class
# 8          9  CA-2017-115812   6/9/2017  6/14/2017  Standard Class
# ...      ...             ...        ...        ...             ...
# 9986    9987  CA-2019-125794  9/29/2019  10/3/2019  Standard Class
# 9990    9991  CA-2020-121258  2/26/2020   3/3/2020  Standard Class
# 9991    9992  CA-2020-121258  2/26/2020   3/3/2020  Standard Class
# 9992    9993  CA-2020-121258  2/26/2020   3/3/2020  Standard Class
# 9993    9994  CA-2020-119914   5/4/2020   5/9/2020    Second Class
#
#      Customer ID    Customer Name    Segment Country/Region         City  ...  \
# 2       DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles  ...
# 5       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 6       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 7       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 8       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# ...          ...              ...        ...            ...          ...  ...
# 9986    ML-17410     Maris LaWare   Consumer  United States  Los Angeles  ...
# 9990    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9991    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9992    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9993    CC-12220     Chris Cortes   Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 2        90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 5        90032.0    West  FUR-FU-10001487        Furniture  Furnishings
# 6        90032.0    West  OFF-AR-10002833  Office Supplies          Art
# 7        90032.0    West  TEC-PH-10002275       Technology       Phones
# 8        90032.0    West  OFF-BI-10003910  Office Supplies      Binders
# ...          ...     ...              ...              ...          ...
# 9986     90008.0    West  TEC-AC-10003399       Technology  Accessories
# 9990     92627.0    West  FUR-FU-10000747        Furniture  Furnishings
# 9991     92627.0    West  TEC-PH-10003645       Technology       Phones
# 9992     92627.0    West  OFF-PA-10004041  Office Supplies        Paper
# 9993     92683.0    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                            Newell 322    7.280         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.152         6
# 8     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# ...                                                 ...      ...       ...
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       Discount   Profit
# 2          0.0   6.8714
# 5          0.0  14.1694
# 6          0.0   1.9656
# 7          0.2  90.7152
# 8          0.2   5.7825
# ...        ...      ...
# 9986       0.0  15.2208
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [2001 rows x 21 columns]

# %%
df_california.to_csv('california_data.csv', index=False)

# %%
 ## TODO-04your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date), send him csv file

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Order Date']
# Out:
# 0      2019-11-08
# 1      2019-11-08
# 2      2019-06-12
# 3      2018-10-11
# 4      2018-10-11
#           ...
# 9989   2017-01-21
# 9990   2020-02-26
# 9991   2020-02-26
# 9992   2020-02-26
# 9993   2020-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
filtered_df = df[
    (df['State'].isin(['California', 'Texas'])) &
    (df['Order Date'].dt.year == 2017)]
filtered_df
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 5          6  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# 6          7  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# 7          8  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# 8          9  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# 9         10  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# ...      ...             ...        ...         ...             ...
# 9885    9886  CA-2017-112291 2017-04-03    4/8/2017  Standard Class
# 9903    9904  CA-2017-122609 2017-11-12  11/18/2017  Standard Class
# 9904    9905  CA-2017-122609 2017-11-12  11/18/2017  Standard Class
# 9942    9943  CA-2017-143371 2017-12-28    1/3/2018  Standard Class
# 9943    9944  CA-2017-143371 2017-12-28    1/3/2018  Standard Class
#
#      Customer ID    Customer Name    Segment Country/Region         City  ...  \
# 5       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 6       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 7       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 8       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 9       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# ...          ...              ...        ...            ...          ...  ...
# 9885    KE-16420  Katrina Edelman  Corporate  United States  Los Angeles  ...
# 9903    DP-13000    Darren Powers   Consumer  United States   Carrollton  ...
# 9904    DP-13000    Darren Powers   Consumer  United States   Carrollton  ...
# 9942    MD-17350    Maribeth Dona   Consumer  United States      Anaheim  ...
# 9943    MD-17350    Maribeth Dona   Consumer  United States      Anaheim  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 5        90032.0     West  FUR-FU-10001487        Furniture  Furnishings
# 6        90032.0     West  OFF-AR-10002833  Office Supplies          Art
# 7        90032.0     West  TEC-PH-10002275       Technology       Phones
# 8        90032.0     West  OFF-BI-10003910  Office Supplies      Binders
# 9        90032.0     West  OFF-AP-10002892  Office Supplies   Appliances
# ...          ...      ...              ...              ...          ...
# 9885     90008.0     West  TEC-AC-10000736       Technology  Accessories
# 9903     75007.0  Central  FUR-FU-10004587        Furniture  Furnishings
# 9904     75007.0  Central  TEC-AC-10002567       Technology  Accessories
# 9942     92804.0     West  OFF-ST-10001128  Office Supplies      Storage
# 9943     92804.0     West  OFF-SU-10002537  Office Supplies     Supplies
#
#                                            Product Name    Sales  Quantity  \
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                            Newell 322    7.280         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.152         6
# 8     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# 9                      Belkin F5C206VTEL 6 Outlet Surge  114.900         5
# ...                                                 ...      ...       ...
# 9885                     Logitech G600 MMO Gaming Mouse  159.980         2
# 9903  GE General Use Halogen Bulbs, 100 Watts, 1 Bul...   25.128         3
# 9904                Logitech G602 Wireless Gaming Mouse  127.984         2
# 9942        Carina Mini System Audio Rack, Model AR050B  998.820         9
# 9943                           Acme Box Cutter Scissors   51.150         5
#
#       Discount   Profit
# 5          0.0  14.1694
# 6          0.0   1.9656
# 7          0.2  90.7152
# 8          0.2   5.7825
# 9          0.0  34.4700
# ...        ...      ...
# 9885       0.0  57.5928
# 9903       0.6  -6.9102
# 9904       0.2  25.5968
# 9942       0.0  29.9646
# 9943       0.0  13.2990
#
# [632 rows x 21 columns]

# %%
filtered_df.to_csv('california_texas_2017_orders.csv', index=False)

# %%
# TODO 05 - how much total sales, average sales, and standard deviation of sales your company make in 2017
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Order Date']
# Out:
# 0      2019-11-08
# 1      2019-11-08
# 2      2019-06-12
# 3      2018-10-11
# 4      2018-10-11
#           ...
# 9989   2017-01-21
# 9990   2020-02-26
# 9991   2020-02-26
# 9992   2020-02-26
# 9993   2020-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
df_2017 = df[df['Order Date'].dt.year == 2017]
df_2017
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 5          6  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# 6          7  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# 7          8  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# 8          9  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# 9         10  CA-2017-115812 2017-06-09   6/14/2017  Standard Class
# ...      ...             ...        ...         ...             ...
# 9946    9947  CA-2017-111157 2017-03-02    3/6/2017  Standard Class
# 9956    9957  US-2017-143287 2017-11-11  11/17/2017  Standard Class
# 9957    9958  US-2017-143287 2017-11-11  11/17/2017  Standard Class
# 9958    9959  US-2017-143287 2017-11-11  11/17/2017  Standard Class
# 9989    9990  CA-2017-110422 2017-01-21   1/23/2017    Second Class
#
#      Customer ID     Customer Name      Segment Country/Region          City  \
# 5       BH-11710   Brosina Hoffman     Consumer  United States   Los Angeles
# 6       BH-11710   Brosina Hoffman     Consumer  United States   Los Angeles
# 7       BH-11710   Brosina Hoffman     Consumer  United States   Los Angeles
# 8       BH-11710   Brosina Hoffman     Consumer  United States   Los Angeles
# 9       BH-11710   Brosina Hoffman     Consumer  United States   Los Angeles
# ...          ...               ...          ...            ...           ...
# 9946    NH-18610     Nicole Hansen    Corporate  United States  Philadelphia
# 9956    KN-16705     Kristina Nunn  Home Office  United States  New Rochelle
# 9957    KN-16705     Kristina Nunn  Home Office  United States  New Rochelle
# 9958    KN-16705     Kristina Nunn  Home Office  United States  New Rochelle
# 9989    TB-21400  Tom Boeckenhauer     Consumer  United States         Miami
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 5     ...     90032.0    West  FUR-FU-10001487        Furniture  Furnishings
# 6     ...     90032.0    West  OFF-AR-10002833  Office Supplies          Art
# 7     ...     90032.0    West  TEC-PH-10002275       Technology       Phones
# 8     ...     90032.0    West  OFF-BI-10003910  Office Supplies      Binders
# 9     ...     90032.0    West  OFF-AP-10002892  Office Supplies   Appliances
# ...   ...         ...     ...              ...              ...          ...
# 9946  ...     19120.0    East  TEC-AC-10004353       Technology  Accessories
# 9956  ...     10801.0    East  OFF-PA-10001776  Office Supplies        Paper
# 9957  ...     10801.0    East  OFF-PA-10004039  Office Supplies        Paper
# 9958  ...     10801.0    East  OFF-SU-10001574  Office Supplies     Supplies
# 9989  ...     33180.0   South  FUR-FU-10001889        Furniture  Furnishings
#
#                                            Product Name    Sales  Quantity  \
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                            Newell 322    7.280         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.152         6
# 8     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# 9                      Belkin F5C206VTEL 6 Outlet Surge  114.900         5
# ...                                                 ...      ...       ...
# 9946                              Hypercom P1300 Pinpad  151.200         3
# 9956  Wirebound Message Books, Four 2 3/4" x 5" Form...   46.350         5
# 9957                                         Xerox 1882  223.920         4
# 9958                           Acme Value Line Scissors    7.300         2
# 9989                             Ultra Door Pull Handle   25.248         3
#
#       Discount    Profit
# 5          0.0   14.1694
# 6          0.0    1.9656
# 7          0.2   90.7152
# 8          0.2    5.7825
# 9          0.0   34.4700
# ...        ...       ...
# 9946       0.2   32.1300
# 9956       0.0   21.7845
# 9957       0.0  109.7208
# 9958       0.0    2.1900
# 9989       0.2    4.1028
#
# [1993 rows x 21 columns]

# %%
total_sales = df_2017['Sales'].sum()
average_sales = df_2017['Sales'].mean()
std_sales = df_2017['Sales'].std()

print("Total Sales:", total_sales)
print("Average Sales:", average_sales)
print("Standard Deviation of Sales:", std_sales)
# Out:
# Total Sales: 484247.4981
# Average Sales: 242.97415860511794
# Standard Deviation of Sales: 754.0533572593688

# %%
# TODO 06 - which Segment has the highest profit in 2018
df_2018 = df[df['Order Date'].dt.year == 2018]
df_2018
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 3          4  US-2018-108966 2018-10-11  10/18/2018  Standard Class
# 4          5  US-2018-108966 2018-10-11  10/18/2018  Standard Class
# 14        15  US-2018-118983 2018-11-22  11/26/2018  Standard Class
# 15        16  US-2018-118983 2018-11-22  11/26/2018  Standard Class
# 24        25  CA-2018-106320 2018-09-25   9/30/2018  Standard Class
# ...      ...             ...        ...         ...             ...
# 9970    9971  CA-2018-103772 2018-06-28    7/2/2018  Standard Class
# 9971    9972  CA-2018-103772 2018-06-28    7/2/2018  Standard Class
# 9980    9981  US-2018-151435 2018-09-06    9/9/2018    Second Class
# 9984    9985  CA-2018-100251 2018-05-17   5/23/2018  Standard Class
# 9985    9986  CA-2018-100251 2018-05-17   5/23/2018  Standard Class
#
#      Customer ID     Customer Name      Segment Country/Region  \
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# 4       SO-20335    Sean O'Donnell     Consumer  United States
# 14      HP-14815     Harold Pawlan  Home Office  United States
# 15      HP-14815     Harold Pawlan  Home Office  United States
# 24      EB-13870       Emily Burns     Consumer  United States
# ...          ...               ...          ...            ...
# 9970    MP-17470       Mark Packer  Home Office  United States
# 9971    MP-17470       Mark Packer  Home Office  United States
# 9980    SW-20455       Shaun Weien     Consumer  United States
# 9984    DV-13465  Dianna Vittorini     Consumer  United States
# 9985    DV-13465  Dianna Vittorini     Consumer  United States
#
#                  City  ... Postal Code   Region       Product ID  \
# 3     Fort Lauderdale  ...     33311.0    South  FUR-TA-10000577
# 4     Fort Lauderdale  ...     33311.0    South  OFF-ST-10000760
# 14         Fort Worth  ...     76106.0  Central  OFF-AP-10002311
# 15         Fort Worth  ...     76106.0  Central  OFF-BI-10000756
# 24               Orem  ...     84057.0     West  FUR-TA-10000577
# ...               ...  ...         ...      ...              ...
# 9970           Smyrna  ...     30080.0    South  OFF-BI-10002867
# 9971           Smyrna  ...     30080.0    South  OFF-AR-10000538
# 9980        Lafayette  ...     70506.0    South  FUR-TA-10001039
# 9984       Long Beach  ...     11561.0     East  OFF-LA-10003766
# 9985       Long Beach  ...     11561.0     East  OFF-SU-10000898
#
#              Category Sub-Category  \
# 3           Furniture       Tables
# 4     Office Supplies      Storage
# 14    Office Supplies   Appliances
# 15    Office Supplies      Binders
# 24          Furniture       Tables
# ...               ...          ...
# 9970  Office Supplies      Binders
# 9971  Office Supplies          Art
# 9980        Furniture       Tables
# 9984  Office Supplies       Labels
# 9985  Office Supplies     Supplies
#
#                                            Product Name      Sales  Quantity  \
# 3         Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 4                        Eldon Fold 'N Roll Cart System    22.3680         2
# 14    Holmes Replacement Filter for HEPA Air Cleaner...    68.8100         5
# 15     Storex DuraTech Recycled Plastic Frosted Binders     2.5440         3
# 24        Bretford CR4500 Series Slim Rectangular Table  1044.6300         3
# ...                                                 ...        ...       ...
# 9970            GBC Recycled Regency Composition Covers   119.5600         2
# 9971  Boston Model 1800 Electric Pencil Sharpener, Gray   140.7500         5
# 9980                         KI Adjustable-Height Table    85.9800         1
# 9984                     Self-Adhesive Removable Labels    31.5000        10
# 9985  Acme Hot Forged Carbon Steel Scissors with Nic...    55.6000         4
#
#       Discount    Profit
# 3         0.45 -383.0310
# 4         0.20    2.5164
# 14        0.80 -123.8580
# 15        0.80   -3.8160
# 24        0.00  240.2649
# ...        ...       ...
# 9970      0.00   54.9976
# 9971      0.00   42.2250
# 9980      0.00   22.3548
# 9984      0.00   15.1200
# 9985      0.00   16.1240
#
# [2102 rows x 21 columns]

# %%
result = df_2018.groupby('Segment')['Profit'].sum()
result
# Out:
# Segment
# Consumer       28460.1665
# Corporate      20688.3248
# Home Office    12470.1124
# Name: Profit, dtype: float64

# %%
highest_profit_segment = result.sort_values(ascending=False)

highest_profit_segment
# Out:
# Segment
# Consumer       28460.1665
# Corporate      20688.3248
# Home Office    12470.1124
# Name: Profit, dtype: float64

# %%
# TODO 07 - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
filtered = df[(df['Order Date'] >= '2019-04-15') & (df['Order Date'] <= '2019-12-31')]
filtered
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2019-152156 2019-11-08  11/11/2019    Second Class
# 1          2  CA-2019-152156 2019-11-08  11/11/2019    Second Class
# 2          3  CA-2019-138688 2019-06-12   6/16/2019    Second Class
# 13        14  CA-2019-161389 2019-12-05  12/10/2019  Standard Class
# 21        22  CA-2019-137330 2019-12-09  12/13/2019  Standard Class
# ...      ...             ...        ...         ...             ...
# 9978    9979  US-2019-103674 2019-12-06  12/10/2019  Standard Class
# 9979    9980  US-2019-103674 2019-12-06  12/10/2019  Standard Class
# 9982    9983  US-2019-157728 2019-09-22   9/28/2019  Standard Class
# 9983    9984  US-2019-157728 2019-09-22   9/28/2019  Standard Class
# 9986    9987  CA-2019-125794 2019-09-29   10/3/2019  Standard Class
#
#      Customer ID    Customer Name      Segment Country/Region          City  \
# 0       CG-12520      Claire Gute     Consumer  United States     Henderson
# 1       CG-12520      Claire Gute     Consumer  United States     Henderson
# 2       DV-13045  Darrin Van Huff    Corporate  United States   Los Angeles
# 13      IM-15070     Irene Maddox     Consumer  United States       Seattle
# 21      KB-16585        Ken Black    Corporate  United States       Fremont
# ...          ...              ...          ...            ...           ...
# 9978    AP-10720       Anne Pryor  Home Office  United States   Los Angeles
# 9979    AP-10720       Anne Pryor  Home Office  United States   Los Angeles
# 9982    RC-19960       Ryan Crowe     Consumer  United States  Grand Rapids
# 9983    RC-19960       Ryan Crowe     Consumer  United States  Grand Rapids
# 9986    ML-17410     Maris LaWare     Consumer  United States   Los Angeles
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 0     ...     42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...     42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 2     ...     90036.0     West  OFF-LA-10000240  Office Supplies       Labels
# 13    ...     98103.0     West  OFF-BI-10003656  Office Supplies      Binders
# 21    ...     68025.0  Central  OFF-AR-10000246  Office Supplies          Art
# ...   ...         ...      ...              ...              ...          ...
# 9978  ...     90032.0     West  OFF-BI-10003727  Office Supplies      Binders
# 9979  ...     90032.0     West  OFF-BI-10002026  Office Supplies      Binders
# 9982  ...     49505.0  Central  OFF-PA-10002195  Office Supplies        Paper
# 9983  ...     49505.0  Central  TEC-PH-10001305       Technology       Phones
# 9986  ...     90008.0     West  TEC-AC-10003399       Technology  Accessories
#
#                                            Product Name    Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.960         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 13          Fellowes PB200 Plastic Comb Binding Machine  407.976         3
# 21                                           Newell 318   19.460         7
# ...                                                 ...      ...       ...
# 9978  Avery Durable Slant Ring Binders With Label Ho...   13.376         4
# 9979                  Ibico Recycled Linen-Style Covers  437.472        14
# 9982  RSVP Cards & Envelopes, Blank White, 8-1/2" X ...   35.560         7
# 9983                   Panasonic KX TS208W Corded phone   97.980         2
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
#
#       Discount    Profit
# 0          0.0   41.9136
# 1          0.0  219.5820
# 2          0.0    6.8714
# 13         0.2  132.5922
# 21         0.0    5.0596
# ...        ...       ...
# 9978       0.2    4.6816
# 9979       0.2  153.1152
# 9982       0.0   16.7132
# 9983       0.0   27.4344
# 9986       0.0   15.2208
#
# [2167 rows x 21 columns]

# %%
 States_less_total = filtered.groupby('State')['Sales'].sum().sort_values().head(5)
 States_less_total
# Out:
# State
# New Hampshire            49.05
# New Mexico               64.08
# District of Columbia    117.07
# Louisiana               249.80
# South Carolina          502.48
# Name: Sales, dtype: float64

# %%
print("5 states with lowest sales (Apr 15 - Dec 31, 2019):")
print(States_less_total)
# Out:
# 5 states with lowest sales (Apr 15 - Dec 31, 2019):
# State
# New Hampshire            49.05
# New Mexico               64.08
# District of Columbia    117.07
# Louisiana               249.80
# South Carolina          502.48
# Name: Sales, dtype: float64

# %%
# TODO 08 - what is the proportion of total sales (%) in West + Central in 2019
df_2019 = df[df['Order Date'].dt.year == 2019]
df_2019
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2019-152156 2019-11-08  11/11/2019    Second Class
# 1          2  CA-2019-152156 2019-11-08  11/11/2019    Second Class
# 2          3  CA-2019-138688 2019-06-12   6/16/2019    Second Class
# 13        14  CA-2019-161389 2019-12-05  12/10/2019  Standard Class
# 21        22  CA-2019-137330 2019-12-09  12/13/2019  Standard Class
# ...      ...             ...        ...         ...             ...
# 9978    9979  US-2019-103674 2019-12-06  12/10/2019  Standard Class
# 9979    9980  US-2019-103674 2019-12-06  12/10/2019  Standard Class
# 9982    9983  US-2019-157728 2019-09-22   9/28/2019  Standard Class
# 9983    9984  US-2019-157728 2019-09-22   9/28/2019  Standard Class
# 9986    9987  CA-2019-125794 2019-09-29   10/3/2019  Standard Class
#
#      Customer ID    Customer Name      Segment Country/Region          City  \
# 0       CG-12520      Claire Gute     Consumer  United States     Henderson
# 1       CG-12520      Claire Gute     Consumer  United States     Henderson
# 2       DV-13045  Darrin Van Huff    Corporate  United States   Los Angeles
# 13      IM-15070     Irene Maddox     Consumer  United States       Seattle
# 21      KB-16585        Ken Black    Corporate  United States       Fremont
# ...          ...              ...          ...            ...           ...
# 9978    AP-10720       Anne Pryor  Home Office  United States   Los Angeles
# 9979    AP-10720       Anne Pryor  Home Office  United States   Los Angeles
# 9982    RC-19960       Ryan Crowe     Consumer  United States  Grand Rapids
# 9983    RC-19960       Ryan Crowe     Consumer  United States  Grand Rapids
# 9986    ML-17410     Maris LaWare     Consumer  United States   Los Angeles
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 0     ...     42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...     42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 2     ...     90036.0     West  OFF-LA-10000240  Office Supplies       Labels
# 13    ...     98103.0     West  OFF-BI-10003656  Office Supplies      Binders
# 21    ...     68025.0  Central  OFF-AR-10000246  Office Supplies          Art
# ...   ...         ...      ...              ...              ...          ...
# 9978  ...     90032.0     West  OFF-BI-10003727  Office Supplies      Binders
# 9979  ...     90032.0     West  OFF-BI-10002026  Office Supplies      Binders
# 9982  ...     49505.0  Central  OFF-PA-10002195  Office Supplies        Paper
# 9983  ...     49505.0  Central  TEC-PH-10001305       Technology       Phones
# 9986  ...     90008.0     West  TEC-AC-10003399       Technology  Accessories
#
#                                            Product Name    Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.960         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 13          Fellowes PB200 Plastic Comb Binding Machine  407.976         3
# 21                                           Newell 318   19.460         7
# ...                                                 ...      ...       ...
# 9978  Avery Durable Slant Ring Binders With Label Ho...   13.376         4
# 9979                  Ibico Recycled Linen-Style Covers  437.472        14
# 9982  RSVP Cards & Envelopes, Blank White, 8-1/2" X ...   35.560         7
# 9983                   Panasonic KX TS208W Corded phone   97.980         2
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
#
#       Discount    Profit
# 0          0.0   41.9136
# 1          0.0  219.5820
# 2          0.0    6.8714
# 13         0.2  132.5922
# 21         0.0    5.0596
# ...        ...       ...
# 9978       0.2    4.6816
# 9979       0.2  153.1152
# 9982       0.0   16.7132
# 9983       0.0   27.4344
# 9986       0.0   15.2208
#
# [2587 rows x 21 columns]

# %%
total_sales = df_2019['Sales'].sum()
west_central_sales = df_2019[df_2019['Region'].isin(['West', 'Central'])]['Sales'].sum()
proportion = (west_central_sales / total_sales) * 100
proportion
# Out:
# np.float64(54.97479891837763)

# %%
print(f"Proportion of West + Central regions in 2019: {proportion:.2f}%")
# Out:
# Proportion of West + Central regions in 2019: 54.97%

# %%
# TODO 09 - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020

# %%
df = df[df['Order Date'].dt.year.isin([2019, 2020])]
df
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2019-152156 2019-11-08  11/11/2019    Second Class
# 1          2  CA-2019-152156 2019-11-08  11/11/2019    Second Class
# 2          3  CA-2019-138688 2019-06-12   6/16/2019    Second Class
# 12        13  CA-2020-114412 2020-04-15   4/20/2020  Standard Class
# 13        14  CA-2019-161389 2019-12-05  12/10/2019  Standard Class
# ...      ...             ...        ...         ...             ...
# 9988    9989  CA-2020-163629 2020-11-17  11/21/2020  Standard Class
# 9990    9991  CA-2020-121258 2020-02-26    3/3/2020  Standard Class
# 9991    9992  CA-2020-121258 2020-02-26    3/3/2020  Standard Class
# 9992    9993  CA-2020-121258 2020-02-26    3/3/2020  Standard Class
# 9993    9994  CA-2020-119914 2020-05-04    5/9/2020    Second Class
#
#      Customer ID    Customer Name    Segment Country/Region         City  ...  \
# 0       CG-12520      Claire Gute   Consumer  United States    Henderson  ...
# 1       CG-12520      Claire Gute   Consumer  United States    Henderson  ...
# 2       DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles  ...
# 12      AA-10480     Andrew Allen   Consumer  United States      Concord  ...
# 13      IM-15070     Irene Maddox   Consumer  United States      Seattle  ...
# ...          ...              ...        ...            ...          ...  ...
# 9988    RA-19885     Ruben Ausman  Corporate  United States       Athens  ...
# 9990    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9991    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9992    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9993    CC-12220     Chris Cortes   Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 0        42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2        90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 12       28027.0   South  OFF-PA-10002365  Office Supplies        Paper
# 13       98103.0    West  OFF-BI-10003656  Office Supplies      Binders
# ...          ...     ...              ...              ...          ...
# 9988     30605.0   South  TEC-PH-10004006       Technology       Phones
# 9990     92627.0    West  FUR-FU-10000747        Furniture  Furnishings
# 9991     92627.0    West  TEC-PH-10003645       Technology       Phones
# 9992     92627.0    West  OFF-PA-10004041  Office Supplies        Paper
# 9993     92683.0    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.960         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 12                                           Xerox 1967   15.552         3
# 13          Fellowes PB200 Plastic Comb Binding Machine  407.976         3
# ...                                                 ...      ...       ...
# 9988                    Panasonic KX - TS880B Telephone  206.100         5
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       Discount    Profit
# 0          0.0   41.9136
# 1          0.0  219.5820
# 2          0.0    6.8714
# 12         0.2    5.4432
# 13         0.2  132.5922
# ...        ...       ...
# 9988       0.0   55.6470
# 9990       0.0   15.6332
# 9991       0.2   19.3932
# 9992       0.0   13.3200
# 9993       0.0   72.9480
#
# [5899 rows x 21 columns]
# Warning: Total number of columns (21) exceeds max_columns (20) limiting to first (20) columns.
# Warning: Total number of columns (21) exceeds max_columns (20) limiting to first (20) columns.

# %%
order_counts = df.groupby('Product Name')['Order ID'].nunique().reset_index()
order_counts.columns = ['Product Name', 'Order Count']

# %%
sales = df.groupby('Product Name')['Sales'].sum().reset_index()
sales
# Out:
#                                            Product Name    Sales
# 0     "While you Were Out" Message Book, One Form pe...   25.228
# 1              #10 Gummed Flap White Envelopes, 100/Box   34.692
# 2                         #10 Self-Seal White Envelopes  108.682
# 3            #10 White Business Envelopes,4 1/8 x 9 1/2  319.668
# 4               #10- 4 1/8" x 9 1/2" Recycled Envelopes   89.148
# ...                                                 ...      ...
# 1736  iKross Bluetooth Portable Keyboard + Cell Phon...  226.260
# 1737                         iOttie HLCRIO102 Car Mount  175.912
# 1738                                iOttie XL Car Mount  223.888
# 1739  invisibleSHIELD by ZAGG Smudge-Free Screen Pro...  366.996
# 1740                 netTALK DUO VoIP Telephone Service  545.896
#
# [1741 rows x 2 columns]

# %%
result = pd.merge(order_counts, sales, on='Product Name')
result
# Out:
#                                            Product Name  Order Count    Sales
# 0     "While you Were Out" Message Book, One Form pe...            3   25.228
# 1              #10 Gummed Flap White Envelopes, 100/Box            3   34.692
# 2                         #10 Self-Seal White Envelopes            4  108.682
# 3            #10 White Business Envelopes,4 1/8 x 9 1/2            4  319.668
# 4               #10- 4 1/8" x 9 1/2" Recycled Envelopes            3   89.148
# ...                                                 ...          ...      ...
# 1736  iKross Bluetooth Portable Keyboard + Cell Phon...            3  226.260
# 1737                         iOttie HLCRIO102 Car Mount            3  175.912
# 1738                                iOttie XL Car Mount            2  223.888
# 1739  invisibleSHIELD by ZAGG Smudge-Free Screen Pro...            5  366.996
# 1740                 netTALK DUO VoIP Telephone Service            2  545.896
#
# [1741 rows x 3 columns]

# %%
# Get top 10 by orders
print("Top 10 by number of orders:")
print(result.sort_values('Order Count', ascending=False).head(10))

# Get top 10 by sales
print("\nTop 10 by total sales:")
print(result.sort_values('Sales', ascending=False).head(10))
# Out:
# Top 10 by number of orders:
#                                          Product Name  Order Count     Sales
# 512                                 Easy-staple paper           27  1481.728
# 1412                                          Staples           24   462.068
# 1406                                  Staple envelope           22   644.936
# 1413                          Staples in misc. colors           13   357.164
# 1409                                   Staple remover           12   204.512
# 411                Chromcraft Round Conference Tables           12  7965.053
# 1421                          Storex Dura Pro Binders           12   176.418
# 250                           Avery Non-Stick Binders           11   122.128
# 732   Global Wood Trimmed Manager's Task Chair, Khaki           11  2793.086
# 654                            GBC Instant Report Kit           10   142.987
#
# Top 10 by total sales:
#                                            Product Name  Order Count  \
# 388               Canon imageCLASS 2200 Advanced Copier            5
# 765                Hewlett Packard LaserJet 3310 Copier            6
# 18     3D Systems Cube Printer, 2nd Generation, Magenta            2
# 651    GBC Ibimaster 500 Manual ProClick Binding System            5
# 649          GBC DocuBind TL300 Electric Binding System            6
# 646           GBC DocuBind P400 Electric Binding System            4
# 1310                            Samsung Galaxy Mega 6.3            5
# 746        HON 5400 Series Task Chairs for Big and Tall            4
# 987   Martin Yale Chadless Opener Electric Letter Op...            4
# 729       Global Troy Executive Leather Low-Back Tilter            7
#
#           Sales
# 388   61599.824
# 765   16079.732
# 18    14299.890
# 651   13621.542
# 649   12737.258
# 646   12521.108
# 1310  12263.708
# 746   11846.562
# 987   11825.902
# 729   10169.894

# %%
# TODO 10 - plot at least 2 plots, any plot you think interesting :)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Sales', data=df, estimator=sum, ci=None)
plt.title('Total Sales by Product Category')
plt.ylabel('Sales ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('category_sales.png')
# Out:
# <ipython-input-119-f2f6c958a445>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Category', y='Sales', data=df, estimator=sum, ci=None)

# %%
plt.figure(figsize=(10, 6))
region_profit = df.groupby('Region')['Profit'].sum().reset_index()
sns.histplot(x='Region', y='Profit', data=region_profit)
plt.title('Total Profit by Region')
plt.ylabel('Profit ($)')
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.savefig('region_profit.png')

# %%
df["Sales"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Region'].value_counts().plot(kind='bar', color=['skyblue', 'salmon', 'yellow', 'red'])
# Out:
# <Axes: xlabel='Region'>

# %%
# TODO Bonus - use np.where() to create new column in dataframe to help you answer your own questions
import numpy as np

# %%
df['Profit_Status'] = np.where(df['Profit'] > 200, 'Profitable', 'Unprofitable')
df['Profit_Status']
# Out:
# 0       Unprofitable
# 1         Profitable
# 2       Unprofitable
# 12      Unprofitable
# 13      Unprofitable
#             ...
# 9988    Unprofitable
# 9990    Unprofitable
# 9991    Unprofitable
# 9992    Unprofitable
# 9993    Unprofitable
# Name: Profit_Status, Length: 5899, dtype: object

# %%
status_count = df['Profit_Status'].value_counts()
print("Number of profitable vs unprofitable transactions:")
print(status_count)
# Out:
# Number of profitable vs unprofitable transactions:
# Profit_Status
# Unprofitable    5652
# Profitable       247
# Name: count, dtype: int64

# %%
category_status = df.groupby(['Category', 'Profit_Status']).size().unstack()
print("\nProfitability by category:")
print(category_status)
# Out:
# Profitability by category:
# Profit_Status    Profitable  Unprofitable
# Category
# Furniture                59          1189
# Office Supplies          88          3480
# Technology              100           983

# %%
df['High_Discount'] = np.where(df['Discount'] >= 0.2, 'Yes', 'No')
discount_analysis = pd.crosstab(df['High_Discount'], df['Profit_Status'])
print("\nRelationship between high discounts and profitability:")
print(discount_analysis)
# Out:
# Relationship between high discounts and profitability:
# Profit_Status  Profitable  Unprofitable
# High_Discount
# No                    194          2723
# Yes                    53          2929
